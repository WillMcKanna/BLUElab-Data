# %% [markdown]
# **BLUElab Data - Winter 2026**
# Contributors: Will McKanna, Alex Lang, Kasia Burtell
#
# Python - Jupyter Notebook for Data Cleaning Subteam

# %%
# Import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
